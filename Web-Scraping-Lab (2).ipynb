# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# * Extract information from a given web site
# * Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
#!pip install pandas==1.3.3
#!pip install requests==2.26.0
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y
# !pip install lxml==4.6.4
#!pip install plotly==5.3.1
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['bs4==4.10.0']
#
# pkgs/main/noarch         [<=>                 ] (00m:00s)
# pkgs/main/noarch         [=>                ] (00m:00s) 496  B / ?? (3.22 KB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 496  B / ?? (3.22 KB/s)
# pkgs/main/linux-64       [<=>                 ] (00m:00s)
# pkgs/main/noarch         [=>                ] (00m:00s) 496  B / ?? (3.22 KB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 496  B / ?? (3.22 KB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 732 KB / ?? (2.38 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 732 KB / ?? (2.38 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [<=>                 ] (00m:00s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 732 KB / ?? (2.38 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 732 KB / ?? (2.38 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 732 KB / ?? (2.38 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 652 KB / ?? (2.11 MB/s)
# pkgs/main/noarch         [ <=>                ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 652 KB / ?? (2.11 MB/s)
# pkgs/main/noarch         [ <=>                ] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 652 KB / ?? (2.11 MB/s)
# pkgs/main/noarch         [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 652 KB / ?? (2.11 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Done
# pkgs/r/noarch            [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/main/linux-64       [<=>               ] (00m:00s) 636 KB / ?? (2.07 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.82 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.82 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 696 KB / ?? (2.26 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.82 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) 1 MB / ?? (2.85 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.82 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.82 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Done
# pkgs/r/linux-64          [====================] (00m:00s) Done
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.82 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.82 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.44 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 2 MB / ?? (3.44 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 3 MB / ?? (3.63 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.63 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.71 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 3 MB / ?? (3.71 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 4 MB / ?? (3.82 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:00s) 4 MB / ?? (3.82 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:00s) 5 MB / ?? (3.95 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:01s) Finalizing...
# pkgs/main/linux-64       [      <=>           ] (00m:01s) Done
# pkgs/main/linux-64       [====================] (00m:01s) Done
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - bs4==4.10.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build           Channel                  Size
# ────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────
#
#   + bs4                  4.10.0  hd3eb1b0_0      pkgs/main/noarch        10 KB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates   2022.9.24  ha878542_0      installed
#   + ca-certificates  2023.01.10  h06a4308_0      pkgs/main/linux-64     120 KB
#   - certifi           2022.9.24  pyhd8ed1ab_0    installed
#   + certifi           2022.12.7  py37h06a4308_0  pkgs/main/linux-64     150 KB
#   - openssl              1.1.1s  h0b41bf4_1      installed
#   + openssl              1.1.1t  h7f8727e_0      pkgs/main/linux-64       4 MB
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - beautifulsoup4       4.11.1  pyha770c72_0    installed
#   + beautifulsoup4       4.10.0  pyh06a4308_0    pkgs/main/noarch        85 KB
#
#   Summary:
#
#   Install: 1 packages
#   Upgrade: 3 packages
#   Downgrade: 1 packages
#
#   Total download: 4 MB
#
# ────────────────────────────────────────────────────────────────────────────────
#
# Downloading  [>                                        ] (00m:00s)    3.31 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)    3.31 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  749.27 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished ca-certificates                      (00m:00s)             120 KB    750 KB/s
# Downloading  [>                                        ] (00m:00s)  749.27 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=>                                       ] (00m:00s)  801.79 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=>                                       ] (00m:00s)  801.79 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=>                                       ] (00m:00s)  801.79 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished bs4                                  (00m:00s)              10 KB     62 KB/s
# Downloading  [=>                                       ] (00m:00s)  801.79 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=>                                       ] (00m:00s)  801.79 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==>                                      ] (00m:00s)    1.25 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [===>                                     ] (00m:00s)    2.10 MB/s
# Extracting   [>                                                      ] (--:--)
# Finished beautifulsoup4                       (00m:00s)              85 KB    503 KB/s
# Downloading  [===>                                     ] (00m:00s)    2.10 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [===>                                     ] (00m:00s)    2.10 MB/s
# Extracting   [>                                                      ] (--:--)
# Finished certifi                              (00m:00s)             150 KB    889 KB/s
# Downloading  [===>                                     ] (00m:00s)    2.10 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [===>                                     ] (00m:00s)    2.10 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [===>                                     ] (00m:00s)    2.10 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [===>                                     ] (00m:00s)    2.10 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Finished openssl                              (00m:00s)               4 MB     21 MB/s
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [========================>                ] (00m:00s)        3 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [========================>                ] (00m:00s)        3 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Downloading  [=========================================] (00m:00s)   22.87 MB/s
# Extracting   [=========================================] (00m:00s)        5 / 5
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['html5lib==1.1']
#
# pkgs/main/linux-64       Using cache
# pkgs/main/noarch         Using cache
# pkgs/r/linux-64          Using cache
# pkgs/r/noarch            Using cache
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - html5lib==1.1
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package         Version  Build         Channel                 Size
# ───────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────
#
#   + html5lib          1.1  pyhd3eb1b0_0  pkgs/main/noarch       91 KB
#   + webencodings    0.5.1  py37_1        pkgs/main/linux-64     19 KB
#
#   Summary:
#
#   Install: 2 packages
#
#   Total download: 110 KB
#
# ───────────────────────────────────────────────────────────────────────
#
# Downloading  [=================================>       ] (00m:00s)  644.13 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished html5lib                             (00m:00s)              91 KB    644 KB/s
# Downloading  [=================================>       ] (00m:00s)  644.13 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  644.13 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  644.13 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  747.73 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished webencodings                         (00m:00s)              19 KB    129 KB/s
# Downloading  [=========================================] (00m:00s)  747.73 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  747.73 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  747.73 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  747.73 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  747.73 KB/s
# Extracting   [=========================================] (00m:00s)        2 / 2
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting lxml==4.6.4
#   Downloading lxml-4.6.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 76.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: lxml
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.1
#     Uninstalling lxml-4.9.1:
#       Successfully uninstalled lxml-4.9.1
# Successfully installed lxml-4.6.4

# %% [markdown]
# Download the webpage at the url

# %%
# your code goes here
import requests
data = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
# your code goes here
from bs4 import BeautifulSoup
soup = BeautifulSoup(data, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_390/2881979473.py in <module>
#       1 # your code goes here
#       2 from bs4 import BeautifulSoup
# ----> 3 soup = BeautifulSoup(data, 'html.parser', header=0)
#
# ~/conda/envs/python/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     252         # with the remaining **kwargs.
#     253         if builder is None:
# --> 254             builder = builder_class(**kwargs)
#     255             if not original_builder and not (
#     256                     original_features == builder.NAME or
#
# ~/conda/envs/python/lib/python3.7/site-packages/bs4/builder/_htmlparser.py in __init__(self, parser_args, parser_kwargs, **kwargs)
#     323                 value = kwargs.pop(arg)
#     324                 extra_parser_kwargs[arg] = value
# --> 325         super(HTMLParserTreeBuilder, self).__init__(**kwargs)
#     326         parser_args = parser_args or []
#     327         parser_kwargs = parser_kwargs or {}
#
# TypeError: __init__() got an unexpected keyword argument 'header'

# %%
import pandas as pd
job_data = pd.read_html(str(soup),header=0)
job_data = job_data[0]
job_data
# Out:
#    No.    Language                                 Created By  \
# 0    1      Python                           Guido van Rossum
# 1    2        Java                              James Gosling
# 2    3           R               Robert Gentleman, Ross Ihaka
# 3    4  Javascript                                   Netscape
# 4    5       Swift                                      Apple
# 5    6         C++                          Bjarne Stroustrup
# 6    7          C#                                  Microsoft
# 7    8         PHP                             Rasmus Lerdorf
# 8    9         SQL    Donald D. Chamberlin, Raymond F. Boyce.
# 9   10          Go  Robert Griesemer, Ken Thompson, Rob Pike.
#
#   Average Annual Salary Learning Difficulty
# 0              $114,383                Easy
# 1              $101,013                Easy
# 2               $92,037                Hard
# 3              $110,981                Easy
# 4              $130,801                Easy
# 5              $113,865                Hard
# 6               $88,726                Hard
# 7               $84,727                Easy
# 8               $84,793                Easy
# 9               $94,082           Difficult

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
job_data[['Language','Average Annual Salary']]
# Out:
#      Language Average Annual Salary
# 0      Python              $114,383
# 1        Java              $101,013
# 2           R               $92,037
# 3  Javascript              $110,981
# 4       Swift              $130,801
# 5         C++              $113,865
# 6          C#               $88,726
# 7         PHP               $84,727
# 8         SQL               $84,793
# 9          Go               $94,082

# %%
#table = soup.find('table')

# %%
#Get all rows from the table
#for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    #cols = row.find_all('td') # in html a column is represented by the tag <td>
    #color_name = cols[1].getText() # store the value in column 3 as color_name
    #color_code = cols[3].getText() # store the value in column 4 as color_code
    #print("{}--->{}".format(color_name,color_code))

# %%
#import pandas as pd
#df = pd.DataFrame(columns=['Language', 'Average_Annual_Salary'])

#for row in soup.find("tbody").find_all("tr"):
    #col = row.find_all("td")
    #Language = col[1]
    #Name = col[1]
    #Salary = col[3]
    #Level = col[3]

    #df = df.append({'Language':Language, 'Average_Annual_Salary':Salary}, ignore_index=True)
    #df

# %%
#df

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
job_data.to_csv('job_data.csv')

# %%
df2 = pd.DataFrame(df)
df2.to_csv('C:\\Users\kaush\OneDrive\Documents\job.csv', index=False)

# %%
df2
# Out:
#         Language    Average_Annual_Salary
# 0     [Language]  [Average Annual Salary]
# 1       [Python]               [$114,383]
# 2         [Java]               [$101,013]
# 3            [R]                [$92,037]
# 4   [Javascript]               [$110,981]
# 5        [Swift]               [$130,801]
# 6          [C++]               [$113,865]
# 7           [C#]                [$88,726]
# 8          [PHP]                [$84,727]
# 9          [SQL]                [$84,793]
# 10          [Go]                [$94,082]

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01).
